# %%
# Libraries

import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import make_scorer, fbeta_score, accuracy_score
from model_selection.functional_grid import FunctionalGridSearch
import multiprocessing
from model_selection.logs import logs_by_fold, logs_by_candidate
multiprocessing.set_start_method(method='fork', force=True)

# %% [markdown]
# ### Functional GridSearchCV Setup

# %%
# Load dataset


X,y = load_breast_cancer(return_X_y=True, as_frame=True)

# Define an estimator

estimator = RandomForestClassifier(random_state=1)

# Grid with hyperparameter values 

param_grid = {
    "n_estimators": [100, 300],
    "max_depth": [None, 10, 20],
    "min_samples_split": [2, 5],
    "min_samples_leaf": [1, 2],
    "bootstrap": [True]
}

# Two performance metrics to monitor during grid search

f2_scorer = make_scorer(fbeta_score, beta=2)
acc_scorer = make_scorer(accuracy_score)

# GridSearchCV

search = FunctionalGridSearch(
    estimator=estimator,
    param_grid=param_grid,
    cv=5,
    scoring={'f2':f2_scorer, 'accuracy':acc_scorer},        
    n_jobs=1,           
    return_train_score=True,
    refit='f2',
    calibrate=True,      
    verbose=-1
).fit(X,y)

# %% [markdown]
# ### Results
#
# <ol>
#     <li>GridSearchCV results. </li>
#     <p></p>
#     <li>Best estimator based on the refitted performance metric.</li>
#     <p></p>
#     <li>Best estimator based on the one-standard-error-rule.</li>
#     <p></p>
#     <li>Best estimator based on the one-standard-error-rule and calibration.</li>
#     <p></p>
#     <li>Calibration results.</li>
#     <p></p>
#     <li>Execution traces (general, grouped by candidate, group by fold).</li>
# </ol>

# %%
# Functional GridSearchCV results

pd.DataFrame(search.cv_results_).sort_values(by='mean_test_f2', ascending=False)
# Out:
#                                                params  param_n_estimators  \
# 12  {'n_estimators': 300, 'max_depth': None, 'min_...                 300
# 20  {'n_estimators': 300, 'max_depth': 20, 'min_sa...                 300
# 16  {'n_estimators': 300, 'max_depth': 10, 'min_sa...                 300
# 9   {'n_estimators': 100, 'max_depth': 20, 'min_sa...                 100
# 5   {'n_estimators': 100, 'max_depth': 10, 'min_sa...                 100
# 1   {'n_estimators': 100, 'max_depth': None, 'min_...                 100
# 2   {'n_estimators': 100, 'max_depth': None, 'min_...                 100
# 6   {'n_estimators': 100, 'max_depth': 10, 'min_sa...                 100
# 10  {'n_estimators': 100, 'max_depth': 20, 'min_sa...                 100
# 0   {'n_estimators': 100, 'max_depth': None, 'min_...                 100
# 8   {'n_estimators': 100, 'max_depth': 20, 'min_sa...                 100
# 4   {'n_estimators': 100, 'max_depth': 10, 'min_sa...                 100
# 13  {'n_estimators': 300, 'max_depth': None, 'min_...                 300
# 17  {'n_estimators': 300, 'max_depth': 10, 'min_sa...                 300
# 21  {'n_estimators': 300, 'max_depth': 20, 'min_sa...                 300
# 14  {'n_estimators': 300, 'max_depth': None, 'min_...                 300
# 18  {'n_estimators': 300, 'max_depth': 10, 'min_sa...                 300
# 22  {'n_estimators': 300, 'max_depth': 20, 'min_sa...                 300
# 15  {'n_estimators': 300, 'max_depth': None, 'min_...                 300
# 19  {'n_estimators': 300, 'max_depth': 10, 'min_sa...                 300
# 23  {'n_estimators': 300, 'max_depth': 20, 'min_sa...                 300
# 11  {'n_estimators': 100, 'max_depth': 20, 'min_sa...                 100
# 7   {'n_estimators': 100, 'max_depth': 10, 'min_sa...                 100
# 3   {'n_estimators': 100, 'max_depth': None, 'min_...                 100
#
#     param_max_depth  param_min_samples_split  param_min_samples_leaf  \
# 12              NaN                        2                       1
# 20             20.0                        2                       1
# 16             10.0                        2                       1
# 9              20.0                        2                       2
# 5              10.0                        2                       2
# 1               NaN                        2                       2
# 2               NaN                        5                       1
# 6              10.0                        5                       1
# 10             20.0                        5                       1
# 0               NaN                        2                       1
# 8              20.0                        2                       1
# 4              10.0                        2                       1
# 13              NaN                        2                       2
# 17             10.0                        2                       2
# 21             20.0                        2                       2
# 14              NaN                        5                       1
# 18             10.0                        5                       1
# 22             20.0                        5                       1
# 15              NaN                        5                       2
# 19             10.0                        5                       2
# 23             20.0                        5                       2
# 11             20.0                        5                       2
# 7              10.0                        5                       2
# 3               NaN                        5                       2
#
#     param_bootstrap  split0_fit_time  split1_fit_time  split2_fit_time  \
# 12             True         0.175764         0.178261         0.181900
# 20             True         0.181894         0.183788         0.188754
# 16             True         0.184204         0.179442         0.184403
# 9              True         0.058486         0.058166         0.060795
# 5              True         0.059339         0.063418         0.065497
# 1              True         0.058237         0.059657         0.065166
# 2              True         0.059207         0.061926         0.069633
# 6              True         0.065258         0.067648         0.063744
# 10             True         0.059200         0.059487         0.061292
# 0              True         0.070072         0.059673         0.062988
# 8              True         0.058939         0.059924         0.062962
# 4              True         0.059688         0.060029         0.063358
# 13             True         0.191713         0.174910         0.179045
# 17             True         0.174300         0.176176         0.180977
# 21             True         0.174706         0.178583         0.181579
# 14             True         0.183862         0.186833         0.199288
# 18             True         0.177537         0.180576         0.201918
# 22             True         0.180819         0.183211         0.191455
# 15             True         0.181052         0.184450         0.187249
# 19             True         0.174305         0.176833         0.180385
# 23             True         0.177781         0.179479         0.183621
# 11             True         0.057976         0.058733         0.059869
# 7              True         0.059694         0.059479         0.060599
# 3              True         0.063524         0.062791         0.060848
#
#     split3_fit_time  ...  split0_train_accuracy  split1_train_accuracy  \
# 12         0.179561  ...               1.000000               1.000000
# 20         0.182565  ...               1.000000               1.000000
# 16         0.181554  ...               1.000000               1.000000
# 9          0.058650  ...               0.995604               0.993407
# 5          0.067054  ...               0.995604               0.993407
# 1          0.059786  ...               0.995604               0.993407
# 2          0.066805  ...               0.997802               0.995604
# 6          0.063189  ...               0.997802               0.995604
# 10         0.060006  ...               0.997802               0.995604
# 0          0.059945  ...               1.000000               1.000000
# 8          0.059675  ...               1.000000               1.000000
# 10            0.001390                  19
# 0             0.000000                   7
# 8             0.000000                  11
# 4             0.000000                  13
# 13            0.001074                  16
# 17            0.001074                  17
# 21            0.001074                  18
# 14            0.001390                   5
# 18            0.001390                   4
# 22            0.001390                   6
# 15            0.000878                   9
# 19            0.000878                   8
# 23            0.000878                  10
# 11            0.001641                  24
# 7             0.001641                  20
# 3             0.001641                  22
#
# [24 rows x 50 columns]

# %%
# Display best estimator

search.best_estimator_
# Out:
# RandomForestClassifier(n_estimators=300, random_state=1)

# %%
# Display best calibrated estimator 

search.best_calibrated_estimator_.value
# Out:
# CalibratedClassifierCV(cv=5,
#                        estimator=RandomForestClassifier(n_estimators=300,
#                                                         random_state=1),
#                        method='isotonic')

# %%
# Display best least complex model

search.one_se_estimator_.value
# Out:
# RandomForestClassifier(random_state=1)

# %%
# Display best calibrated least complex model

search.one_se_calibrated_estimator_.value
# Out:
# CalibratedClassifierCV(cv=5, estimator=RandomForestClassifier(random_state=1),
#                        method='isotonic')

# %%
# Display best calibrated least complex model's calibration results

if search.one_se_calibration_results_.is_just:
    print(search.one_se_calibration_results_.value)
# Out:
# {'best_model': CalibratedClassifierCV(cv=5, estimator=RandomForestClassifier(random_state=1),
#                        method='isotonic'), 'best_method': 'isotonic', 'best_ece': 0.015441967240078257, 'isotonic_ece': 0.015441967240078257, 'sigmoid_ece': 0.036700749736940444}

# %%
search.get_execution_logs()
# Out:
# {'by_fold': {0: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 0}],
#   1: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 1}],
#   2: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 2}],
#   3: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 3}],
#   4: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 4},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 4}]},
#  'by_candidate': {0: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 4}],
#   1: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 4}],
#   2: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 4}],
#   3: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 4}],
#   4: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 4}],
#   5: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 4}],
#   6: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 4}],
#   7: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 4}],
#   8: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 4}],
#   9: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 4}],
#   10: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 4}],
#   11: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 4}],
#   12: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 4}],
#   13: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 4}],
#   14: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 4}],
#   15: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 4}],
#   16: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 4}],
#   17: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 4}],
#   18: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 4}],
#   19: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 4}],
#   20: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 4}],
#   21: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 4}],
#   22: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 4}],
#   23: [{'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 0},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 1},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 2},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 3},
#    {'stage': 'init',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 4}]}}

# %%
search.get_execution_logs()["by_candidate"]
# Out:
# {0: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 4}],
#  1: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 4}],
#  2: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 4}],
#  3: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 4}],
#  4: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 4}],
#  5: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 4}],
#  6: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 4}],
#  7: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 4}],
#  8: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 4}],
#  9: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 4}],
#  10: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 4}],
#  11: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 4}],
#  12: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 4}],
#  13: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 4}],
#  14: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 4}],
#  15: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 4}],
#  16: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 4}],
#  17: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 4}],
#  18: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 4}],
#  19: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 4}],
#  20: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 4}],
#  21: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 4}],
#  22: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 4}],
#  23: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 4}]}

# %%
search.get_execution_logs()["by_fold"]
# Out:
# {0: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 0},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 0}],
#  1: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 1},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 1}],
#  2: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 2},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 2}],
#  3: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 3},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 3}],
#  4: [{'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 4},
#   {'stage': 'init',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 4}]}
