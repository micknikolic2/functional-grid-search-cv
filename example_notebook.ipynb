# %%
# Libraries

import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import make_scorer, fbeta_score, accuracy_score
from model_selection.functional_grid import FunctionalGridSearch
import multiprocessing
from model_selection.logs import logs_by_fold, logs_by_candidate
multiprocessing.set_start_method(method='fork', force=True)

# %% [markdown]
# ### Functional GridSearchCV Setup

# %%
# Load dataset
X,y = load_breast_cancer(return_X_y=True, as_frame=True)

# Define an estimator
estimator = RandomForestClassifier(random_state=1)

# Grid with hyperparameter values 
param_grid = {
    "n_estimators": [100, 300],
    "max_depth": [None, 10, 20],
    "min_samples_split": [2, 5],
    "min_samples_leaf": [1, 2],
    "bootstrap": [True]
}

# Two performance metrics to monitor during grid search
f2_scorer = make_scorer(fbeta_score, beta=2)
acc_scorer = make_scorer(accuracy_score)

# GridSearchCV
search = FunctionalGridSearch(
    estimator=estimator,
    param_grid=param_grid,
    cv=5,
    scoring={'f2': f2_scorer, 'accuracy': acc_scorer},
    n_jobs=1,
    return_train_score=True,
    refit='f2',
    calibrate=True,
    verbose=-1,
    R=4,       
    N=1_000_000 
).fit(X, y)

# %% [markdown]
# ### Results
#
# <ol>
#     <li>GridSearchCV results. </li>
#     <p></p>
#     <li>Best estimator based on the refitted performance metric.</li>
#     <p></p>
#     <li>Best estimator based on the one-standard-error-rule.</li>
#     <p></p>
#     <li>Best estimator based on the one-standard-error-rule and calibration.</li>
#     <p></p>
#     <li>Calibration results.</li>
#     <p></p>
#     <li>Execution traces (general, grouped by candidate, group by fold).</li>
# </ol>

# %%
# Functional GridSearchCV results

pd.DataFrame(search.cv_results_).sort_values(by='mean_test_f2', ascending=False)
# Out:
#                                                params  param_n_estimators  \
# 12  {'n_estimators': 300, 'max_depth': None, 'min_...                 300
# 20  {'n_estimators': 300, 'max_depth': 20, 'min_sa...                 300
# 16  {'n_estimators': 300, 'max_depth': 10, 'min_sa...                 300
# 9   {'n_estimators': 100, 'max_depth': 20, 'min_sa...                 100
# 5   {'n_estimators': 100, 'max_depth': 10, 'min_sa...                 100
# 1   {'n_estimators': 100, 'max_depth': None, 'min_...                 100
# 2   {'n_estimators': 100, 'max_depth': None, 'min_...                 100
# 6   {'n_estimators': 100, 'max_depth': 10, 'min_sa...                 100
# 10  {'n_estimators': 100, 'max_depth': 20, 'min_sa...                 100
# 0   {'n_estimators': 100, 'max_depth': None, 'min_...                 100
# 8   {'n_estimators': 100, 'max_depth': 20, 'min_sa...                 100
# 4   {'n_estimators': 100, 'max_depth': 10, 'min_sa...                 100
# 13  {'n_estimators': 300, 'max_depth': None, 'min_...                 300
# 17  {'n_estimators': 300, 'max_depth': 10, 'min_sa...                 300
# 21  {'n_estimators': 300, 'max_depth': 20, 'min_sa...                 300
# 14  {'n_estimators': 300, 'max_depth': None, 'min_...                 300
# 18  {'n_estimators': 300, 'max_depth': 10, 'min_sa...                 300
# 22  {'n_estimators': 300, 'max_depth': 20, 'min_sa...                 300
# 15  {'n_estimators': 300, 'max_depth': None, 'min_...                 300
# 19  {'n_estimators': 300, 'max_depth': 10, 'min_sa...                 300
# 23  {'n_estimators': 300, 'max_depth': 20, 'min_sa...                 300
# 11  {'n_estimators': 100, 'max_depth': 20, 'min_sa...                 100
# 7   {'n_estimators': 100, 'max_depth': 10, 'min_sa...                 100
# 3   {'n_estimators': 100, 'max_depth': None, 'min_...                 100
#
#     param_max_depth  param_min_samples_split  param_min_samples_leaf  \
# 12              NaN                        2                       1
# 20             20.0                        2                       1
# 16             10.0                        2                       1
# 9              20.0                        2                       2
# 5              10.0                        2                       2
# 1               NaN                        2                       2
# 2               NaN                        5                       1
# 6              10.0                        5                       1
# 10             20.0                        5                       1
# 0               NaN                        2                       1
# 8              20.0                        2                       1
# 4              10.0                        2                       1
# 13              NaN                        2                       2
# 17             10.0                        2                       2
# 21             20.0                        2                       2
# 14              NaN                        5                       1
# 18             10.0                        5                       1
# 22             20.0                        5                       1
# 15              NaN                        5                       2
# 19             10.0                        5                       2
# 23             20.0                        5                       2
# 11             20.0                        5                       2
# 7              10.0                        5                       2
# 3               NaN                        5                       2
#
#     param_bootstrap  split0_fit_time  split1_fit_time  split2_fit_time  \
# 12             True         0.181966         0.183794         0.189772
# 20             True         0.228570         0.201852         0.201161
# 16             True         0.180568         0.184812         0.188831
# 9              True         0.059771         0.060401         0.061398
# 5              True         0.059376         0.060676         0.062121
# 1              True         0.059936         0.060613         0.062920
# 2              True         0.060874         0.061751         0.062458
# 6              True         0.060391         0.060981         0.062753
# 10             True         0.060983         0.062626         0.063749
# 0              True         0.069402         0.061372         0.063943
# 8              True         0.060121         0.061479         0.063038
# 4              True         0.059746         0.060920         0.064620
# 13             True         0.177616         0.180826         0.186428
# 17             True         0.182803         0.183229         0.186949
# 21             True         0.181662         0.182895         0.186233
# 14             True         0.182385         0.186879         0.187505
# 18             True         0.182779         0.185240         0.189417
# 22             True         0.192134         0.188944         0.191755
# 15             True         0.181027         0.183461         0.187121
# 19             True         0.177926         0.184456         0.188863
# 23             True         0.181793         0.183766         0.187518
# 11             True         0.059093         0.060223         0.062051
# 7              True         0.059046         0.060706         0.062669
# 3              True         0.059457         0.060378         0.061373
#
#     split3_fit_time  ...  split0_train_accuracy  split1_train_accuracy  \
# 12         0.185258  ...               1.000000               1.000000
# 20         0.189953  ...               1.000000               1.000000
# 16         0.185529  ...               1.000000               1.000000
# 9          0.061551  ...               0.995604               0.993407
# 5          0.060575  ...               0.995604               0.993407
# 1          0.060506  ...               0.995604               0.993407
# 2          0.061137  ...               0.997802               0.995604
# 6          0.061595  ...               0.997802               0.995604
# 10         0.061311  ...               0.997802               0.995604
# 0          0.062611  ...               1.000000               1.000000
# 8          0.062315  ...               1.000000               1.000000
# 4          0.062602  ...               1.000000               1.000000
# 13         0.183571  ...               0.995604               0.995604
# 17         0.183644  ...               0.995604               0.995604
# 21         0.182508  ...               0.995604               0.995604
# 14         0.188771  ...               0.995604               0.997802
# 18         0.185241  ...               0.995604               0.997802
# 22         0.190834  ...               0.995604               0.997802
# 15         0.180461  ...               0.995604               0.993407
# 19         0.181775  ...               0.995604               0.993407
# 23         0.183710  ...               0.995604               0.993407
# 11         0.060545  ...               0.995604               0.991209
# 7          0.060950  ...               0.995604               0.991209
# 3          0.060180  ...               0.995604               0.991209
#
#     split2_train_accuracy  split3_train_accuracy  split4_train_accuracy  \
# 12               1.000000               1.000000               1.000000
# 20               1.000000               1.000000               1.000000
# 16               1.000000               1.000000               1.000000
# 9                0.993407               0.993407               0.993421
# 5                0.993407               0.993407               0.993421
# 1                0.993407               0.993407               0.993421
# 2                0.997802               1.000000               0.997807
# 6                0.997802               1.000000               0.997807
# 10               0.997802               1.000000               0.997807
# 0                1.000000               1.000000               1.000000
# 8                1.000000               1.000000               1.000000
# 4                1.000000               1.000000               1.000000
# 13               0.993407               0.993407               0.993421
# 17               0.993407               0.993407               0.993421
# 21               0.993407               0.993407               0.993421
# 14               0.997802               1.000000               0.997807
# 18               0.997802               1.000000               0.997807
# 22               0.997802               1.000000               0.997807
# 15               0.993407               0.993407               0.993421
# 19               0.993407               0.993407               0.993421
# 23               0.993407               0.993407               0.993421
# 11               0.993407               0.993407               0.991228
# 7                0.993407               0.993407               0.991228
# 3                0.993407               0.993407               0.991228
#
#     mean_test_accuracy  std_test_accuracy  mean_train_accuracy  \
# 12            0.963111           0.021030             1.000000
# 20            0.963111           0.021030             1.000000
# 16            0.963111           0.021030             1.000000
# 9             0.959587           0.014230             0.993849
# 5             0.959587           0.014230             0.993849
# 1             0.959587           0.014230             0.993849
# 2             0.957833           0.020287             0.997803
# 6             0.957833           0.020287             0.997803
# 10            0.957833           0.020287             0.997803
# 0             0.959587           0.018878             1.000000
# 8             0.959587           0.018878             1.000000
# 4             0.959587           0.018878             1.000000
# 13            0.959571           0.020473             0.994289
# 17            0.959571           0.020473             0.994289
# 21            0.959571           0.020473             0.994289
# 14            0.959603           0.025154             0.997803
# 18            0.959603           0.025154             0.997803
# 22            0.959603           0.025154             0.997803
# 15            0.959587           0.023261             0.993849
# 19            0.959587           0.023261             0.993849
# 23            0.959587           0.023261             0.993849
# 11            0.957833           0.021752             0.992971
# 7             0.957833           0.021752             0.992971
# 3             0.957833           0.021752             0.992971
#
#     std_train_accuracy  rank_test_accuracy
# 12            0.000000                   3
# 20            0.000000                   1
# 16            0.000000                   2
# 9             0.000878                  15
# 5             0.000878                  12
# 1             0.000878                  14
# 2             0.001390                  23
# 6             0.001390                  21
# 10            0.001390                  19
# 0             0.000000                   7
# 8             0.000000                  11
# 4             0.000000                  13
# 13            0.001074                  16
# 17            0.001074                  17
# 21            0.001074                  18
# 14            0.001390                   5
# 18            0.001390                   4
# 22            0.001390                   6
# 15            0.000878                   9
# 19            0.000878                   8
# 23            0.000878                  10
# 11            0.001641                  24
# 7             0.001641                  20
# 3             0.001641                  22
#
# [24 rows x 57 columns]

# %%
# Display best estimator

search.best_estimator_
# Out:
# RandomForestClassifier(n_estimators=300, random_state=1)

# %% [markdown]
# ### Maybe Monad

# %%
# Display best calibrated estimator 

search.best_calibrated_estimator_.value
# Out:
# CalibratedClassifierCV(cv=5,
#                        estimator=RandomForestClassifier(n_estimators=300,
#                                                         random_state=1),
#                        method='isotonic')

# %%
# Display best least complex model

search.one_se_estimator_.value
# Out:
# RandomForestClassifier(random_state=1)

# %%
# Display best calibrated least complex model

search.one_se_calibrated_estimator_.value
# Out:
# CalibratedClassifierCV(cv=5, estimator=RandomForestClassifier(random_state=1),
#                        method='isotonic')

# %%
# Display best calibrated least complex model's calibration results

if search.one_se_calibration_results_.is_just:
    print(search.one_se_calibration_results_.value)
# Out:
# {'best_model': CalibratedClassifierCV(cv=5, estimator=RandomForestClassifier(random_state=1),
#                        method='isotonic'), 'best_method': 'isotonic', 'best_ece': 0.015441967240078257, 'isotonic_ece': 0.015441967240078257, 'sigmoid_ece': 0.036700749736940444}

# %% [markdown]
# ### Writer Monad

# %%
search.get_execution_logs()
# Out:
# {'by_fold': {0: [{'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 0,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 0,
#     'split_index': 0,
#     'fit_time': 0.071807861328125,
#     'score_time': 0.007704973220825195},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 0,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 1,
#     'split_index': 0,
#     'fit_time': 0.06125473976135254,
#     'score_time': 0.007403850555419922},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 0,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 2,
#     'split_index': 0,
#     'fit_time': 0.06523895263671875,
#     'score_time': 0.00671696662902832},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 0,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 3,
#     'split_index': 0,
#     'fit_time': 0.062333106994628906,
#     'score_time': 0.006865024566650391},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 0,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 4,
#     'split_index': 0,
#     'fit_time': 0.05976295471191406,
#     'score_time': 0.00661015510559082},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 0,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 5,
#     'split_index': 0,
#     'fit_time': 0.06059741973876953,
#     'score_time': 0.00684809684753418},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 0,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 6,
#     'split_index': 0,
#     'fit_time': 0.059509992599487305,
#     'score_time': 0.006591320037841797},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 0,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 7,
#     'split_index': 0,
#     'fit_time': 0.05798697471618652,
#     'score_time': 0.006517887115478516},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 0,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 8,
#     'split_index': 0,
#     'fit_time': 0.05902910232543945,
#     'score_time': 0.0064923763275146484},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 0,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 9,
#     'split_index': 0,
#     'fit_time': 0.05791306495666504,
#     'score_time': 0.006615161895751953},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 0,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 10,
#     'split_index': 0,
#     'fit_time': 0.05971884727478027,
#     'score_time': 0.006575107574462891},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 0,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 11,
#     'split_index': 0,
#     'fit_time': 0.058120012283325195,
#     'score_time': 0.006420135498046875},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 12,
#     'split_index': 0,
#     'fit_time': 0.17839503288269043,
#     'score_time': 0.016749143600463867},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 13,
#     'split_index': 0,
#     'fit_time': 0.18329882621765137,
#     'score_time': 0.018349170684814453},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 14,
#     'split_index': 0,
#     'fit_time': 0.18945980072021484,
#     'score_time': 0.01859593391418457},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 15,
#     'split_index': 0,
#     'fit_time': 0.17622900009155273,
#     'score_time': 0.01685786247253418},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 16,
#     'split_index': 0,
#     'fit_time': 0.18282699584960938,
#     'score_time': 0.0189669132232666},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 17,
#     'split_index': 0,
#     'fit_time': 0.17739176750183105,
#     'score_time': 0.017555952072143555},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 18,
#     'split_index': 0,
#     'fit_time': 0.17802906036376953,
#     'score_time': 0.018741846084594727},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 19,
#     'split_index': 0,
#     'fit_time': 0.17336010932922363,
#     'score_time': 0.016630172729492188},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 20,
#     'split_index': 0,
#     'fit_time': 0.17937898635864258,
#     'score_time': 0.017452001571655273},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 21,
#     'split_index': 0,
#     'fit_time': 0.1751689910888672,
#     'score_time': 0.01674199104309082},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 22,
#     'split_index': 0,
#     'fit_time': 0.17876577377319336,
#     'score_time': 0.017052888870239258},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 23,
#     'split_index': 0,
#     'fit_time': 0.18651914596557617,
#     'score_time': 0.017714738845825195}],
#   1: [{'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 1,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 0,
#     'split_index': 1,
#     'fit_time': 0.062116146087646484,
#     'score_time': 0.006979942321777344},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 1,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 1,
#     'split_index': 1,
#     'fit_time': 0.06451821327209473,
#     'score_time': 0.0073299407958984375},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 1,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 2,
#     'split_index': 1,
#     'fit_time': 0.06090712547302246,
#     'score_time': 0.006676197052001953},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 1,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 3,
#     'split_index': 1,
#     'fit_time': 0.06159687042236328,
#     'score_time': 0.006498098373413086},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 1,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 4,
#     'split_index': 1,
#     'fit_time': 0.06111788749694824,
#     'score_time': 0.006806135177612305},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 1,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 5,
#     'split_index': 1,
#     'fit_time': 0.0592808723449707,
#     'score_time': 0.006513833999633789},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 1,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 6,
#     'split_index': 1,
#     'fit_time': 0.05996584892272949,
#     'score_time': 0.00632476806640625},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 1,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 7,
#     'split_index': 1,
#     'fit_time': 0.0606689453125,
#     'score_time': 0.006628990173339844},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 1,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 8,
#     'split_index': 1,
#     'fit_time': 0.06048464775085449,
#     'score_time': 0.006402015686035156},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 1,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 9,
#     'split_index': 1,
#     'fit_time': 0.058338165283203125,
#     'score_time': 0.006387948989868164},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 1,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 10,
#     'split_index': 1,
#     'fit_time': 0.05991339683532715,
#     'score_time': 0.0063419342041015625},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 1,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 11,
#     'split_index': 1,
#     'fit_time': 0.05885791778564453,
#     'score_time': 0.0063402652740478516},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 12,
#     'split_index': 1,
#     'fit_time': 0.179229736328125,
#     'score_time': 0.016583919525146484},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 13,
#     'split_index': 1,
#     'fit_time': 0.18447613716125488,
#     'score_time': 0.017866134643554688},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 14,
#     'split_index': 1,
#     'fit_time': 0.19305968284606934,
#     'score_time': 0.017867088317871094},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 15,
#     'split_index': 1,
#     'fit_time': 0.17798614501953125,
#     'score_time': 0.01647806167602539},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 16,
#     'split_index': 1,
#     'fit_time': 0.19304275512695312,
#     'score_time': 0.018635034561157227},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 17,
#     'split_index': 1,
#     'fit_time': 0.17786312103271484,
#     'score_time': 0.017168760299682617},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 18,
#     'split_index': 1,
#     'fit_time': 0.19455790519714355,
#     'score_time': 0.018512964248657227},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 19,
#     'split_index': 1,
#     'fit_time': 0.1784811019897461,
#     'score_time': 0.01648998260498047},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 20,
#     'split_index': 1,
#     'fit_time': 0.18131709098815918,
#     'score_time': 0.0169069766998291},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 21,
#     'split_index': 1,
#     'fit_time': 0.17874598503112793,
#     'score_time': 0.016605854034423828},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 22,
#     'split_index': 1,
#     'fit_time': 0.18119025230407715,
#     'score_time': 0.017783641815185547},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 23,
#     'split_index': 1,
#     'fit_time': 0.18387985229492188,
#     'score_time': 0.01711273193359375}],
#   2: [{'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 2,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 0,
#     'split_index': 2,
#     'fit_time': 0.08983182907104492,
#     'score_time': 0.0068628787994384766},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 2,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 1,
#     'split_index': 2,
#     'fit_time': 0.06694293022155762,
#     'score_time': 0.00753474235534668},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 2,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 2,
#     'split_index': 2,
#     'fit_time': 0.06236910820007324,
#     'score_time': 0.006526947021484375},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 2,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 3,
#     'split_index': 2,
#     'fit_time': 0.060658931732177734,
#     'score_time': 0.006716251373291016},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 2,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 4,
#     'split_index': 2,
#     'fit_time': 0.06340289115905762,
#     'score_time': 0.006758928298950195},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 2,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 5,
#     'split_index': 2,
#     'fit_time': 0.06046795845031738,
#     'score_time': 0.006667137145996094},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 2,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 6,
#     'split_index': 2,
#     'fit_time': 0.062294960021972656,
#     'score_time': 0.0067369937896728516},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 2,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 7,
#     'split_index': 2,
#     'fit_time': 0.061322927474975586,
#     'score_time': 0.0066297054290771484},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 2,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 8,
#     'split_index': 2,
#     'fit_time': 0.06249594688415527,
#     'score_time': 0.006626129150390625},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 2,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 9,
#     'split_index': 2,
#     'fit_time': 0.06044793128967285,
#     'score_time': 0.006949901580810547},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 2,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 10,
#     'split_index': 2,
#     'fit_time': 0.06188702583312988,
#     'score_time': 0.006710052490234375},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 2,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 11,
#     'split_index': 2,
#     'fit_time': 0.06051921844482422,
#     'score_time': 0.006517171859741211},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 12,
#     'split_index': 2,
#     'fit_time': 0.18494296073913574,
#     'score_time': 0.018325090408325195},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 13,
#     'split_index': 2,
#     'fit_time': 0.21643376350402832,
#     'score_time': 0.017423152923583984},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 14,
#     'split_index': 2,
#     'fit_time': 0.19684576988220215,
#     'score_time': 0.018759965896606445},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 15,
#     'split_index': 2,
#     'fit_time': 0.1818981170654297,
#     'score_time': 0.0169370174407959},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 16,
#     'split_index': 2,
#     'fit_time': 0.19366097450256348,
#     'score_time': 0.0172116756439209},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 17,
#     'split_index': 2,
#     'fit_time': 0.1827099323272705,
#     'score_time': 0.01705622673034668},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 18,
#     'split_index': 2,
#     'fit_time': 0.20942997932434082,
#     'score_time': 0.019403934478759766},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 19,
#     'split_index': 2,
#     'fit_time': 0.1815049648284912,
#     'score_time': 0.016949176788330078},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 20,
#     'split_index': 2,
#     'fit_time': 0.18625998497009277,
#     'score_time': 0.017306804656982422},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 21,
#     'split_index': 2,
#     'fit_time': 0.18332505226135254,
#     'score_time': 0.017130136489868164},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 22,
#     'split_index': 2,
#     'fit_time': 0.1911182403564453,
#     'score_time': 0.01926112174987793},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 23,
#     'split_index': 2,
#     'fit_time': 0.18672895431518555,
#     'score_time': 0.018045902252197266}],
#   3: [{'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 3,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 0,
#     'split_index': 3,
#     'fit_time': 0.0615229606628418,
#     'score_time': 0.006691694259643555},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 3,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 1,
#     'split_index': 3,
#     'fit_time': 0.06307506561279297,
#     'score_time': 0.007185935974121094},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 3,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 2,
#     'split_index': 3,
#     'fit_time': 0.0646669864654541,
#     'score_time': 0.007384061813354492},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 3,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 3,
#     'split_index': 3,
#     'fit_time': 0.06018996238708496,
#     'score_time': 0.00678706169128418},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 3,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 4,
#     'split_index': 3,
#     'fit_time': 0.06208992004394531,
#     'score_time': 0.006957054138183594},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 3,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 5,
#     'split_index': 3,
#     'fit_time': 0.059737205505371094,
#     'score_time': 0.006700992584228516},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 3,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 6,
#     'split_index': 3,
#     'fit_time': 0.06046104431152344,
#     'score_time': 0.006559133529663086},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 3,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 7,
#     'split_index': 3,
#     'fit_time': 0.06031322479248047,
#     'score_time': 0.006495952606201172},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 3,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 8,
#     'split_index': 3,
#     'fit_time': 0.06069684028625488,
#     'score_time': 0.006676912307739258},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 3,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 9,
#     'split_index': 3,
#     'fit_time': 0.05934500694274902,
#     'score_time': 0.0064809322357177734},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 3,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 10,
#     'split_index': 3,
#     'fit_time': 0.061251163482666016,
#     'score_time': 0.0063838958740234375},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 3,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 11,
#     'split_index': 3,
#     'fit_time': 0.05967402458190918,
#     'score_time': 0.006758928298950195},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 12,
#     'split_index': 3,
#     'fit_time': 0.19243288040161133,
#     'score_time': 0.018412113189697266},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 13,
#     'split_index': 3,
#     'fit_time': 0.17915582656860352,
#     'score_time': 0.016871929168701172},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 14,
#     'split_index': 3,
#     'fit_time': 0.18996524810791016,
#     'score_time': 0.01730203628540039},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 15,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 15,
#     'split_index': 3,
#     'fit_time': 0.1772911548614502,
#     'score_time': 0.0167849063873291},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 16,
#     'split_index': 3,
#     'fit_time': 0.1825089454650879,
#     'score_time': 0.017447948455810547},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 17,
#     'split_index': 3,
#     'fit_time': 0.1789569854736328,
#     'score_time': 0.017178773880004883},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 18,
#     'split_index': 3,
#     'fit_time': 0.1907048225402832,
#     'score_time': 0.017013072967529297},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 19,
#     'split_index': 3,
#     'fit_time': 0.17775321006774902,
#     'score_time': 0.016891956329345703},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 20,
#     'split_index': 3,
#     'fit_time': 0.18211674690246582,
#     'score_time': 0.01706218719482422},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 21,
#     'split_index': 3,
#     'fit_time': 0.17730998992919922,
#     'score_time': 0.01717209815979004},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 22,
#     'split_index': 3,
#     'fit_time': 0.20003914833068848,
#     'score_time': 0.019588232040405273},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 23,
#     'split_index': 3,
#     'fit_time': 0.19028687477111816,
#     'score_time': 0.018227815628051758}],
#   4: [{'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 0,
#     'split_index': 4,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 0,
#     'split_index': 4,
#     'fit_time': 0.06164193153381348,
#     'score_time': 0.007023811340332031},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 1,
#     'split_index': 4,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 1,
#     'split_index': 4,
#     'fit_time': 0.06393074989318848,
#     'score_time': 0.007440090179443359},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 2,
#     'split_index': 4,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 2,
#     'split_index': 4,
#     'fit_time': 0.06493616104125977,
#     'score_time': 0.007421255111694336},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 3,
#     'split_index': 4,
#     'params': {'n_estimators': 100,
#      'max_depth': None,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 3,
#     'split_index': 4,
#     'fit_time': 0.05938220024108887,
#     'score_time': 0.006587028503417969},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 4,
#     'split_index': 4,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 4,
#     'split_index': 4,
#     'fit_time': 0.06443119049072266,
#     'score_time': 0.006994962692260742},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 5,
#     'split_index': 4,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 5,
#     'split_index': 4,
#     'fit_time': 0.060112953186035156,
#     'score_time': 0.006888866424560547},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 6,
#     'split_index': 4,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 6,
#     'split_index': 4,
#     'fit_time': 0.06232023239135742,
#     'score_time': 0.007150888442993164},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 7,
#     'split_index': 4,
#     'params': {'n_estimators': 100,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 7,
#     'split_index': 4,
#     'fit_time': 0.05985522270202637,
#     'score_time': 0.006641864776611328},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 8,
#     'split_index': 4,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 8,
#     'split_index': 4,
#     'fit_time': 0.06166505813598633,
#     'score_time': 0.0066983699798583984},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 9,
#     'split_index': 4,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 9,
#     'split_index': 4,
#     'fit_time': 0.06068611145019531,
#     'score_time': 0.006704807281494141},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 10,
#     'split_index': 4,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 10,
#     'split_index': 4,
#     'fit_time': 0.06127119064331055,
#     'score_time': 0.006871223449707031},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 11,
#     'split_index': 4,
#     'params': {'n_estimators': 100,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 11,
#     'split_index': 4,
#     'fit_time': 0.05955195426940918,
#     'score_time': 0.006664276123046875},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 12,
#     'split_index': 4,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 12,
#     'split_index': 4,
#     'fit_time': 0.1950080394744873,
#     'score_time': 0.018007755279541016},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 13,
#     'split_index': 4,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 13,
#     'split_index': 4,
#     'fit_time': 0.1834099292755127,
#     'score_time': 0.0173947811126709},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 14,
#     'split_index': 4,
#     'params': {'n_estimators': 300,
#      'max_depth': None,
# ...
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 16,
#     'split_index': 3,
#     'fit_time': 0.1825089454650879,
#     'score_time': 0.017447948455810547},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 16,
#     'split_index': 4,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 16,
#     'split_index': 4,
#     'fit_time': 0.18536901473999023,
#     'score_time': 0.017421960830688477}],
#   17: [{'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 17,
#     'split_index': 0,
#     'fit_time': 0.17739176750183105,
#     'score_time': 0.017555952072143555},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 17,
#     'split_index': 1,
#     'fit_time': 0.17786312103271484,
#     'score_time': 0.017168760299682617},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 17,
#     'split_index': 2,
#     'fit_time': 0.1827099323272705,
#     'score_time': 0.01705622673034668},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 17,
#     'split_index': 3,
#     'fit_time': 0.1789569854736328,
#     'score_time': 0.017178773880004883},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 17,
#     'split_index': 4,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 17,
#     'split_index': 4,
#     'fit_time': 0.18053770065307617,
#     'score_time': 0.017281055450439453}],
#   18: [{'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 18,
#     'split_index': 0,
#     'fit_time': 0.17802906036376953,
#     'score_time': 0.018741846084594727},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 18,
#     'split_index': 1,
#     'fit_time': 0.19455790519714355,
#     'score_time': 0.018512964248657227},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 18,
#     'split_index': 2,
#     'fit_time': 0.20942997932434082,
#     'score_time': 0.019403934478759766},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 18,
#     'split_index': 3,
#     'fit_time': 0.1907048225402832,
#     'score_time': 0.017013072967529297},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 18,
#     'split_index': 4,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 18,
#     'split_index': 4,
#     'fit_time': 0.18554973602294922,
#     'score_time': 0.017190933227539062}],
#   19: [{'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 19,
#     'split_index': 0,
#     'fit_time': 0.17336010932922363,
#     'score_time': 0.016630172729492188},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 19,
#     'split_index': 1,
#     'fit_time': 0.1784811019897461,
#     'score_time': 0.01648998260498047},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 19,
#     'split_index': 2,
#     'fit_time': 0.1815049648284912,
#     'score_time': 0.016949176788330078},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 19,
#     'split_index': 3,
#     'fit_time': 0.17775321006774902,
#     'score_time': 0.016891956329345703},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 19,
#     'split_index': 4,
#     'params': {'n_estimators': 300,
#      'max_depth': 10,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 19,
#     'split_index': 4,
#     'fit_time': 0.18045997619628906,
#     'score_time': 0.017410755157470703}],
#   20: [{'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 20,
#     'split_index': 0,
#     'fit_time': 0.17937898635864258,
#     'score_time': 0.017452001571655273},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 20,
#     'split_index': 1,
#     'fit_time': 0.18131709098815918,
#     'score_time': 0.0169069766998291},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 20,
#     'split_index': 2,
#     'fit_time': 0.18625998497009277,
#     'score_time': 0.017306804656982422},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 20,
#     'split_index': 3,
#     'fit_time': 0.18211674690246582,
#     'score_time': 0.01706218719482422},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 20,
#     'split_index': 4,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 20,
#     'split_index': 4,
#     'fit_time': 0.18545985221862793,
#     'score_time': 0.017547130584716797}],
#   21: [{'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 21,
#     'split_index': 0,
#     'fit_time': 0.1751689910888672,
#     'score_time': 0.01674199104309082},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 21,
#     'split_index': 1,
#     'fit_time': 0.17874598503112793,
#     'score_time': 0.016605854034423828},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 21,
#     'split_index': 2,
#     'fit_time': 0.18332505226135254,
#     'score_time': 0.017130136489868164},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 21,
#     'split_index': 3,
#     'fit_time': 0.17730998992919922,
#     'score_time': 0.01717209815979004},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 21,
#     'split_index': 4,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 2,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 21,
#     'split_index': 4,
#     'fit_time': 0.18088412284851074,
#     'score_time': 0.017494916915893555}],
#   22: [{'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 22,
#     'split_index': 0,
#     'fit_time': 0.17876577377319336,
#     'score_time': 0.017052888870239258},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 22,
#     'split_index': 1,
#     'fit_time': 0.18119025230407715,
#     'score_time': 0.017783641815185547},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 22,
#     'split_index': 2,
#     'fit_time': 0.1911182403564453,
#     'score_time': 0.01926112174987793},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 22,
#     'split_index': 3,
#     'fit_time': 0.20003914833068848,
#     'score_time': 0.019588232040405273},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 22,
#     'split_index': 4,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 1,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 22,
#     'split_index': 4,
#     'fit_time': 0.22197318077087402,
#     'score_time': 0.019841909408569336}],
#   23: [{'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 0,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 23,
#     'split_index': 0,
#     'fit_time': 0.18651914596557617,
#     'score_time': 0.017714738845825195},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 1,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 23,
#     'split_index': 1,
#     'fit_time': 0.18387985229492188,
#     'score_time': 0.01711273193359375},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 2,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 23,
#     'split_index': 2,
#     'fit_time': 0.18672895431518555,
#     'score_time': 0.018045902252197266},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 3,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 23,
#     'split_index': 3,
#     'fit_time': 0.19028687477111816,
#     'score_time': 0.018227815628051758},
#    {'stage': 'fit_and_score',
#     'event': 'estimator_cloned',
#     'candidate_index': 23,
#     'split_index': 4,
#     'params': {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_split': 5,
#      'min_samples_leaf': 2,
#      'bootstrap': True}},
#    {'stage': 'timing',
#     'event': 'timing_recorded',
#     'candidate_index': 23,
#     'split_index': 4,
#     'fit_time': 0.1930248737335205,
#     'score_time': 0.01853013038635254}]}}

# %%
search.get_execution_logs()["by_candidate"]
# Out:
# {0: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 0,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0012888908386230469},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 0,
#    'split_index': 0,
#    'fit_time': 0.06940221786499023,
#    'predict_time': 0.0012888908386230469,
#    'score_time': 0.00710296630859375},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 0,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0012018680572509766},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 0,
#    'split_index': 1,
#    'fit_time': 0.06137204170227051,
#    'predict_time': 0.0012018680572509766,
#    'score_time': 0.006680011749267578},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 0,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0010943412780761719},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 0,
#    'split_index': 2,
#    'fit_time': 0.06394314765930176,
#    'predict_time': 0.0010943412780761719,
#    'score_time': 0.0066869258880615234},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 0,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011241436004638672},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 0,
#    'split_index': 3,
#    'fit_time': 0.06261110305786133,
#    'predict_time': 0.0011241436004638672,
#    'score_time': 0.007140159606933594},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 0,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011031627655029297},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 0,
#    'split_index': 4,
#    'fit_time': 0.06324315071105957,
#    'predict_time': 0.0011031627655029297,
#    'score_time': 0.006734132766723633}],
#  1: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 1,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0010979175567626953},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 1,
#    'split_index': 0,
#    'fit_time': 0.0599360466003418,
#    'predict_time': 0.0010979175567626953,
#    'score_time': 0.006556987762451172},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 1,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011408329010009766},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 1,
#    'split_index': 1,
#    'fit_time': 0.060613155364990234,
#    'predict_time': 0.0011408329010009766,
#    'score_time': 0.0065801143646240234},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 1,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0010249614715576172},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 1,
#    'split_index': 2,
#    'fit_time': 0.06291985511779785,
#    'predict_time': 0.0010249614715576172,
#    'score_time': 0.00644373893737793},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 1,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011279582977294922},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 1,
#    'split_index': 3,
#    'fit_time': 0.06050586700439453,
#    'predict_time': 0.0011279582977294922,
#    'score_time': 0.006700992584228516},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 1,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011708736419677734},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 1,
#    'split_index': 4,
#    'fit_time': 0.060075998306274414,
#    'predict_time': 0.0011708736419677734,
#    'score_time': 0.006831169128417969}],
#  2: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 2,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011219978332519531},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 2,
#    'split_index': 0,
#    'fit_time': 0.060873985290527344,
#    'predict_time': 0.0011219978332519531,
#    'score_time': 0.006479024887084961},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 2,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.001146078109741211},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 2,
#    'split_index': 1,
#    'fit_time': 0.06175065040588379,
#    'predict_time': 0.001146078109741211,
#    'score_time': 0.0068149566650390625},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 2,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011377334594726562},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 2,
#    'split_index': 2,
#    'fit_time': 0.062458038330078125,
#    'predict_time': 0.0011377334594726562,
#    'score_time': 0.006596803665161133},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 2,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.001135110855102539},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 2,
#    'split_index': 3,
#    'fit_time': 0.06113696098327637,
#    'predict_time': 0.001135110855102539,
#    'score_time': 0.006615161895751953},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 2,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011148452758789062},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 2,
#    'split_index': 4,
#    'fit_time': 0.06322622299194336,
#    'predict_time': 0.0011148452758789062,
#    'score_time': 0.006808042526245117}],
#  3: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 3,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011417865753173828},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 3,
#    'split_index': 0,
#    'fit_time': 0.05945706367492676,
#    'predict_time': 0.0011417865753173828,
#    'score_time': 0.00664520263671875},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 3,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011200904846191406},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 3,
#    'split_index': 1,
#    'fit_time': 0.06037783622741699,
#    'predict_time': 0.0011200904846191406,
#    'score_time': 0.006709098815917969},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 3,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011191368103027344},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 3,
#    'split_index': 2,
#    'fit_time': 0.061372995376586914,
#    'predict_time': 0.0011191368103027344,
#    'score_time': 0.006824016571044922},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 3,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011272430419921875},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 3,
#    'split_index': 3,
#    'fit_time': 0.060179948806762695,
#    'predict_time': 0.0011272430419921875,
#    'score_time': 0.006755828857421875},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 3,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011320114135742188},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 3,
#    'split_index': 4,
#    'fit_time': 0.060716867446899414,
#    'predict_time': 0.0011320114135742188,
#    'score_time': 0.006827831268310547}],
#  4: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 4,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011110305786132812},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 4,
#    'split_index': 0,
#    'fit_time': 0.05974626541137695,
#    'predict_time': 0.0011110305786132812,
#    'score_time': 0.0066030025482177734},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 4,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.001196146011352539},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 4,
#    'split_index': 1,
#    'fit_time': 0.060919761657714844,
#    'predict_time': 0.001196146011352539,
#    'score_time': 0.006807088851928711},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 4,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0012066364288330078},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 4,
#    'split_index': 2,
#    'fit_time': 0.0646200180053711,
#    'predict_time': 0.0012066364288330078,
#    'score_time': 0.0066454410552978516},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 4,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011339187622070312},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 4,
#    'split_index': 3,
#    'fit_time': 0.06260228157043457,
#    'predict_time': 0.0011339187622070312,
#    'score_time': 0.006766080856323242},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 4,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.001132965087890625},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 4,
#    'split_index': 4,
#    'fit_time': 0.06287884712219238,
#    'predict_time': 0.001132965087890625,
#    'score_time': 0.006706953048706055}],
#  5: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 5,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.001123666763305664},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 5,
#    'split_index': 0,
#    'fit_time': 0.05937623977661133,
#    'predict_time': 0.001123666763305664,
#    'score_time': 0.006721019744873047},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 5,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0010387897491455078},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 5,
#    'split_index': 1,
#    'fit_time': 0.06067609786987305,
#    'predict_time': 0.0010387897491455078,
#    'score_time': 0.006616115570068359},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 5,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011332035064697266},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 5,
#    'split_index': 2,
#    'fit_time': 0.06212115287780762,
#    'predict_time': 0.0011332035064697266,
#    'score_time': 0.006804943084716797},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 5,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011188983917236328},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 5,
#    'split_index': 3,
#    'fit_time': 0.060575008392333984,
#    'predict_time': 0.0011188983917236328,
#    'score_time': 0.0064809322357177734},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 5,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0012738704681396484},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 5,
#    'split_index': 4,
#    'fit_time': 0.061399221420288086,
#    'predict_time': 0.0012738704681396484,
#    'score_time': 0.006724119186401367}],
#  6: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 6,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.001135110855102539},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 6,
#    'split_index': 0,
#    'fit_time': 0.06039094924926758,
#    'predict_time': 0.001135110855102539,
#    'score_time': 0.0066988468170166016},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 6,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011131763458251953},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 6,
#    'split_index': 1,
#    'fit_time': 0.060981035232543945,
#    'predict_time': 0.0011131763458251953,
#    'score_time': 0.006536006927490234},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 6,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.001096963882446289},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 6,
#    'split_index': 2,
#    'fit_time': 0.06275296211242676,
#    'predict_time': 0.001096963882446289,
#    'score_time': 0.006700038909912109},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 6,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0010716915130615234},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 6,
#    'split_index': 3,
#    'fit_time': 0.06159520149230957,
#    'predict_time': 0.0010716915130615234,
#    'score_time': 0.006742000579833984},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 6,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0010759830474853516},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 6,
#    'split_index': 4,
#    'fit_time': 0.06415796279907227,
#    'predict_time': 0.0010759830474853516,
#    'score_time': 0.006543874740600586}],
#  7: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 7,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011529922485351562},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 7,
#    'split_index': 0,
#    'fit_time': 0.059046268463134766,
#    'predict_time': 0.0011529922485351562,
#    'score_time': 0.006536960601806641},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 7,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0010857582092285156},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 7,
#    'split_index': 1,
#    'fit_time': 0.06070590019226074,
#    'predict_time': 0.0010857582092285156,
#    'score_time': 0.006416797637939453},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 7,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.001116037368774414},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 7,
#    'split_index': 2,
#    'fit_time': 0.0626688003540039,
#    'predict_time': 0.001116037368774414,
#    'score_time': 0.006684303283691406},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 7,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0010759830474853516},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 7,
#    'split_index': 3,
#    'fit_time': 0.06095004081726074,
#    'predict_time': 0.0010759830474853516,
#    'score_time': 0.006987094879150391},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 7,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011000633239746094},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 7,
#    'split_index': 4,
#    'fit_time': 0.06042075157165527,
#    'predict_time': 0.0011000633239746094,
#    'score_time': 0.006726264953613281}],
#  8: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 8,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011909008026123047},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 8,
#    'split_index': 0,
#    'fit_time': 0.06012129783630371,
#    'predict_time': 0.0011909008026123047,
#    'score_time': 0.006711006164550781},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 8,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011069774627685547},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 8,
#    'split_index': 1,
#    'fit_time': 0.06147909164428711,
#    'predict_time': 0.0011069774627685547,
#    'score_time': 0.0066339969635009766},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 8,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011119842529296875},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 8,
#    'split_index': 2,
#    'fit_time': 0.06303834915161133,
#    'predict_time': 0.0011119842529296875,
#    'score_time': 0.006682157516479492},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 8,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.001177072525024414},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 8,
#    'split_index': 3,
#    'fit_time': 0.06231498718261719,
#    'predict_time': 0.001177072525024414,
#    'score_time': 0.0069348812103271484},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 8,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0012099742889404297},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 8,
#    'split_index': 4,
#    'fit_time': 0.06422591209411621,
#    'predict_time': 0.0012099742889404297,
#    'score_time': 0.006871938705444336}],
#  9: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 9,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011279582977294922},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 9,
#    'split_index': 0,
#    'fit_time': 0.05977129936218262,
#    'predict_time': 0.0011279582977294922,
#    'score_time': 0.006640911102294922},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 9,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011799335479736328},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 9,
#    'split_index': 1,
#    'fit_time': 0.06040072441101074,
#    'predict_time': 0.0011799335479736328,
#    'score_time': 0.006578922271728516},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 9,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0010828971862792969},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 9,
#    'split_index': 2,
#    'fit_time': 0.06139802932739258,
#    'predict_time': 0.0010828971862792969,
#    'score_time': 0.006680965423583984},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 9,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011420249938964844},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 9,
#    'split_index': 3,
#    'fit_time': 0.06155109405517578,
#    'predict_time': 0.0011420249938964844,
#    'score_time': 0.006819009780883789},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 9,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0012030601501464844},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 9,
#    'split_index': 4,
#    'fit_time': 0.06122016906738281,
#    'predict_time': 0.0012030601501464844,
#    'score_time': 0.006986856460571289}],
#  10: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 10,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011780261993408203},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 10,
#    'split_index': 0,
#    'fit_time': 0.06098294258117676,
#    'predict_time': 0.0011780261993408203,
#    'score_time': 0.006869077682495117},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 10,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011141300201416016},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 10,
#    'split_index': 1,
#    'fit_time': 0.06262564659118652,
#    'predict_time': 0.0011141300201416016,
#    'score_time': 0.006432056427001953},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 10,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0010149478912353516},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 10,
#    'split_index': 2,
#    'fit_time': 0.06374883651733398,
#    'predict_time': 0.0010149478912353516,
#    'score_time': 0.006475925445556641},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 10,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0010859966278076172},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 10,
#    'split_index': 3,
#    'fit_time': 0.06131100654602051,
#    'predict_time': 0.0010859966278076172,
#    'score_time': 0.006715059280395508},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 10,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.001093149185180664},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 10,
#    'split_index': 4,
#    'fit_time': 0.06293511390686035,
#    'predict_time': 0.001093149185180664,
#    'score_time': 0.006788015365600586}],
#  11: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 11,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0010502338409423828},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 11,
#    'split_index': 0,
#    'fit_time': 0.05909299850463867,
#    'predict_time': 0.0010502338409423828,
#    'score_time': 0.0065610408782958984},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 11,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011000633239746094},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 11,
#    'split_index': 1,
#    'fit_time': 0.06022286415100098,
#    'predict_time': 0.0011000633239746094,
#    'score_time': 0.006545066833496094},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 11,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.001157999038696289},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 11,
#    'split_index': 2,
#    'fit_time': 0.06205105781555176,
#    'predict_time': 0.001157999038696289,
#    'score_time': 0.006515979766845703},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 11,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011363029479980469},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 11,
#    'split_index': 3,
#    'fit_time': 0.06054496765136719,
#    'predict_time': 0.0011363029479980469,
#    'score_time': 0.006574869155883789},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 11,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0011551380157470703},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 11,
#    'split_index': 4,
#    'fit_time': 0.06096601486206055,
#    'predict_time': 0.0011551380157470703,
#    'score_time': 0.006850004196166992}],
#  12: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 12,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003255128860473633},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 12,
#    'split_index': 0,
#    'fit_time': 0.18196606636047363,
#    'predict_time': 0.003255128860473633,
#    'score_time': 0.016966819763183594},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 12,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0032167434692382812},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 12,
#    'split_index': 1,
#    'fit_time': 0.1837940216064453,
#    'predict_time': 0.0032167434692382812,
#    'score_time': 0.016550302505493164},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 12,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.00335693359375},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 12,
#    'split_index': 2,
#    'fit_time': 0.1897718906402588,
#    'predict_time': 0.00335693359375,
#    'score_time': 0.017189979553222656},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 12,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003172636032104492},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 12,
#    'split_index': 3,
#    'fit_time': 0.1852579116821289,
#    'predict_time': 0.003172636032104492,
#    'score_time': 0.017368078231811523},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 12,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.00335693359375},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 12,
#    'split_index': 4,
#    'fit_time': 0.1864027976989746,
#    'predict_time': 0.00335693359375,
#    'score_time': 0.017644882202148438}],
#  13: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 13,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003165006637573242},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 13,
#    'split_index': 0,
#    'fit_time': 0.17761588096618652,
#    'predict_time': 0.003165006637573242,
#    'score_time': 0.017469167709350586},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 13,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0032091140747070312},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 13,
#    'split_index': 1,
#    'fit_time': 0.18082594871520996,
#    'predict_time': 0.0032091140747070312,
#    'score_time': 0.016729116439819336},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 13,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0032300949096679688},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 13,
#    'split_index': 2,
#    'fit_time': 0.18642783164978027,
#    'predict_time': 0.0032300949096679688,
#    'score_time': 0.017259836196899414},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 13,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0033490657806396484},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 13,
#    'split_index': 3,
#    'fit_time': 0.18357086181640625,
#    'predict_time': 0.0033490657806396484,
#    'score_time': 0.018065929412841797},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 13,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003442049026489258},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 13,
#    'split_index': 4,
#    'fit_time': 0.1843700408935547,
#    'predict_time': 0.003442049026489258,
#    'score_time': 0.01829695701599121}],
#  14: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 14,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0032491683959960938},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 14,
#    'split_index': 0,
#    'fit_time': 0.18238472938537598,
#    'predict_time': 0.0032491683959960938,
#    'score_time': 0.01729893684387207},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 14,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003340005874633789},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 14,
#    'split_index': 1,
#    'fit_time': 0.18687915802001953,
#    'predict_time': 0.003340005874633789,
#    'score_time': 0.01705193519592285},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 14,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0033359527587890625},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 14,
#    'split_index': 2,
#    'fit_time': 0.18750524520874023,
#    'predict_time': 0.0033359527587890625,
#    'score_time': 0.01784491539001465},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 14,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0034029483795166016},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 14,
#    'split_index': 3,
#    'fit_time': 0.18877077102661133,
#    'predict_time': 0.0034029483795166016,
#    'score_time': 0.018032073974609375},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 14,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003464937210083008},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 14,
#    'split_index': 4,
#    'fit_time': 0.18967294692993164,
#    'predict_time': 0.003464937210083008,
#    'score_time': 0.018810033798217773}],
#  15: [{'stage': 'fit_and_score',
# ...
#  19: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 19,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0039520263671875},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 19,
#    'split_index': 0,
#    'fit_time': 0.17792606353759766,
#    'predict_time': 0.0039520263671875,
#    'score_time': 0.025235891342163086},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 19,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003245830535888672},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 19,
#    'split_index': 1,
#    'fit_time': 0.18445611000061035,
#    'predict_time': 0.003245830535888672,
#    'score_time': 0.017668962478637695},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 19,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003242015838623047},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 19,
#    'split_index': 2,
#    'fit_time': 0.18886303901672363,
#    'predict_time': 0.003242015838623047,
#    'score_time': 0.017522096633911133},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 19,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0032601356506347656},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 19,
#    'split_index': 3,
#    'fit_time': 0.18177509307861328,
#    'predict_time': 0.0032601356506347656,
#    'score_time': 0.017367124557495117},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 19,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0035707950592041016},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 19,
#    'split_index': 4,
#    'fit_time': 0.18683862686157227,
#    'predict_time': 0.0035707950592041016,
#    'score_time': 0.018087148666381836}],
#  20: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 20,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003699064254760742},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 20,
#    'split_index': 0,
#    'fit_time': 0.22856998443603516,
#    'predict_time': 0.003699064254760742,
#    'score_time': 0.019430875778198242},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 20,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003567934036254883},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 20,
#    'split_index': 1,
#    'fit_time': 0.20185184478759766,
#    'predict_time': 0.003567934036254883,
#    'score_time': 0.018790245056152344},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 20,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003242015838623047},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 20,
#    'split_index': 2,
#    'fit_time': 0.20116114616394043,
#    'predict_time': 0.003242015838623047,
#    'score_time': 0.017943859100341797},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 20,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0034360885620117188},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 20,
#    'split_index': 3,
#    'fit_time': 0.18995308876037598,
#    'predict_time': 0.0034360885620117188,
#    'score_time': 0.017666101455688477},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 20,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003486156463623047},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 20,
#    'split_index': 4,
#    'fit_time': 0.19152092933654785,
#    'predict_time': 0.003486156463623047,
#    'score_time': 0.018043994903564453}],
#  21: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 21,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0035390853881835938},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 21,
#    'split_index': 0,
#    'fit_time': 0.18166208267211914,
#    'predict_time': 0.0035390853881835938,
#    'score_time': 0.017461061477661133},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 21,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0033872127532958984},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 21,
#    'split_index': 1,
#    'fit_time': 0.18289518356323242,
#    'predict_time': 0.0033872127532958984,
#    'score_time': 0.016665935516357422},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 21,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0032682418823242188},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 21,
#    'split_index': 2,
#    'fit_time': 0.1862328052520752,
#    'predict_time': 0.0032682418823242188,
#    'score_time': 0.01749587059020996},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 21,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0033609867095947266},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 21,
#    'split_index': 3,
#    'fit_time': 0.18250775337219238,
#    'predict_time': 0.0033609867095947266,
#    'score_time': 0.017635107040405273},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 21,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0034618377685546875},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 21,
#    'split_index': 4,
#    'fit_time': 0.18528485298156738,
#    'predict_time': 0.0034618377685546875,
#    'score_time': 0.017443180084228516}],
#  22: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 22,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0033731460571289062},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 22,
#    'split_index': 0,
#    'fit_time': 0.19213390350341797,
#    'predict_time': 0.0033731460571289062,
#    'score_time': 0.017673969268798828},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 22,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003217935562133789},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 22,
#    'split_index': 1,
#    'fit_time': 0.18894386291503906,
#    'predict_time': 0.003217935562133789,
#    'score_time': 0.017475128173828125},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 22,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003313779830932617},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 22,
#    'split_index': 2,
#    'fit_time': 0.19175481796264648,
#    'predict_time': 0.003313779830932617,
#    'score_time': 0.017438888549804688},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 22,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003305196762084961},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 22,
#    'split_index': 3,
#    'fit_time': 0.19083404541015625,
#    'predict_time': 0.003305196762084961,
#    'score_time': 0.017836809158325195},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 22,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003507852554321289},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 22,
#    'split_index': 4,
#    'fit_time': 0.19254493713378906,
#    'predict_time': 0.003507852554321289,
#    'score_time': 0.017776012420654297}],
#  23: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 23,
#    'split_index': 0,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0032949447631835938},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 23,
#    'split_index': 0,
#    'fit_time': 0.181793212890625,
#    'predict_time': 0.0032949447631835938,
#    'score_time': 0.0173490047454834},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 23,
#    'split_index': 1,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003377199172973633},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 23,
#    'split_index': 1,
#    'fit_time': 0.18376588821411133,
#    'predict_time': 0.003377199172973633,
#    'score_time': 0.017334699630737305},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 23,
#    'split_index': 2,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003259897232055664},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 23,
#    'split_index': 2,
#    'fit_time': 0.18751788139343262,
#    'predict_time': 0.003259897232055664,
#    'score_time': 0.017330169677734375},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 23,
#    'split_index': 3,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.003345012664794922},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 23,
#    'split_index': 3,
#    'fit_time': 0.18371009826660156,
#    'predict_time': 0.003345012664794922,
#    'score_time': 0.017881155014038086},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'predict',
#    'event': 'predict_timed',
#    'candidate_index': 23,
#    'split_index': 4,
#    'predict_kind': 'predict_proba',
#    'predict_time': 0.0034799575805664062},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 23,
#    'split_index': 4,
#    'fit_time': 0.1859898567199707,
#    'predict_time': 0.0034799575805664062,
#    'score_time': 0.018124103546142578}]}

# %%
search.get_execution_logs()["by_fold"]
# Out:
# {0: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 0,
#    'split_index': 0,
#    'fit_time': 0.071807861328125,
#    'score_time': 0.007704973220825195},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 1,
#    'split_index': 0,
#    'fit_time': 0.06125473976135254,
#    'score_time': 0.007403850555419922},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 2,
#    'split_index': 0,
#    'fit_time': 0.06523895263671875,
#    'score_time': 0.00671696662902832},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 3,
#    'split_index': 0,
#    'fit_time': 0.062333106994628906,
#    'score_time': 0.006865024566650391},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 4,
#    'split_index': 0,
#    'fit_time': 0.05976295471191406,
#    'score_time': 0.00661015510559082},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 5,
#    'split_index': 0,
#    'fit_time': 0.06059741973876953,
#    'score_time': 0.00684809684753418},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 6,
#    'split_index': 0,
#    'fit_time': 0.059509992599487305,
#    'score_time': 0.006591320037841797},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 7,
#    'split_index': 0,
#    'fit_time': 0.05798697471618652,
#    'score_time': 0.006517887115478516},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 8,
#    'split_index': 0,
#    'fit_time': 0.05902910232543945,
#    'score_time': 0.0064923763275146484},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 9,
#    'split_index': 0,
#    'fit_time': 0.05791306495666504,
#    'score_time': 0.006615161895751953},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 10,
#    'split_index': 0,
#    'fit_time': 0.05971884727478027,
#    'score_time': 0.006575107574462891},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 0,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 11,
#    'split_index': 0,
#    'fit_time': 0.058120012283325195,
#    'score_time': 0.006420135498046875},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 12,
#    'split_index': 0,
#    'fit_time': 0.17839503288269043,
#    'score_time': 0.016749143600463867},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 13,
#    'split_index': 0,
#    'fit_time': 0.18329882621765137,
#    'score_time': 0.018349170684814453},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 14,
#    'split_index': 0,
#    'fit_time': 0.18945980072021484,
#    'score_time': 0.01859593391418457},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 15,
#    'split_index': 0,
#    'fit_time': 0.17622900009155273,
#    'score_time': 0.01685786247253418},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 16,
#    'split_index': 0,
#    'fit_time': 0.18282699584960938,
#    'score_time': 0.0189669132232666},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 17,
#    'split_index': 0,
#    'fit_time': 0.17739176750183105,
#    'score_time': 0.017555952072143555},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 18,
#    'split_index': 0,
#    'fit_time': 0.17802906036376953,
#    'score_time': 0.018741846084594727},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 19,
#    'split_index': 0,
#    'fit_time': 0.17336010932922363,
#    'score_time': 0.016630172729492188},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 20,
#    'split_index': 0,
#    'fit_time': 0.17937898635864258,
#    'score_time': 0.017452001571655273},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 21,
#    'split_index': 0,
#    'fit_time': 0.1751689910888672,
#    'score_time': 0.01674199104309082},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 22,
#    'split_index': 0,
#    'fit_time': 0.17876577377319336,
#    'score_time': 0.017052888870239258},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 0,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 23,
#    'split_index': 0,
#    'fit_time': 0.18651914596557617,
#    'score_time': 0.017714738845825195}],
#  1: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 0,
#    'split_index': 1,
#    'fit_time': 0.062116146087646484,
#    'score_time': 0.006979942321777344},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 1,
#    'split_index': 1,
#    'fit_time': 0.06451821327209473,
#    'score_time': 0.0073299407958984375},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 2,
#    'split_index': 1,
#    'fit_time': 0.06090712547302246,
#    'score_time': 0.006676197052001953},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 3,
#    'split_index': 1,
#    'fit_time': 0.06159687042236328,
#    'score_time': 0.006498098373413086},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 4,
#    'split_index': 1,
#    'fit_time': 0.06111788749694824,
#    'score_time': 0.006806135177612305},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 5,
#    'split_index': 1,
#    'fit_time': 0.0592808723449707,
#    'score_time': 0.006513833999633789},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 6,
#    'split_index': 1,
#    'fit_time': 0.05996584892272949,
#    'score_time': 0.00632476806640625},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 7,
#    'split_index': 1,
#    'fit_time': 0.0606689453125,
#    'score_time': 0.006628990173339844},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 8,
#    'split_index': 1,
#    'fit_time': 0.06048464775085449,
#    'score_time': 0.006402015686035156},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 9,
#    'split_index': 1,
#    'fit_time': 0.058338165283203125,
#    'score_time': 0.006387948989868164},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 10,
#    'split_index': 1,
#    'fit_time': 0.05991339683532715,
#    'score_time': 0.0063419342041015625},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 1,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 11,
#    'split_index': 1,
#    'fit_time': 0.05885791778564453,
#    'score_time': 0.0063402652740478516},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 12,
#    'split_index': 1,
#    'fit_time': 0.179229736328125,
#    'score_time': 0.016583919525146484},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 13,
#    'split_index': 1,
#    'fit_time': 0.18447613716125488,
#    'score_time': 0.017866134643554688},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 14,
#    'split_index': 1,
#    'fit_time': 0.19305968284606934,
#    'score_time': 0.017867088317871094},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 15,
#    'split_index': 1,
#    'fit_time': 0.17798614501953125,
#    'score_time': 0.01647806167602539},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 16,
#    'split_index': 1,
#    'fit_time': 0.19304275512695312,
#    'score_time': 0.018635034561157227},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 17,
#    'split_index': 1,
#    'fit_time': 0.17786312103271484,
#    'score_time': 0.017168760299682617},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 18,
#    'split_index': 1,
#    'fit_time': 0.19455790519714355,
#    'score_time': 0.018512964248657227},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 19,
#    'split_index': 1,
#    'fit_time': 0.1784811019897461,
#    'score_time': 0.01648998260498047},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 20,
#    'split_index': 1,
#    'fit_time': 0.18131709098815918,
#    'score_time': 0.0169069766998291},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 21,
#    'split_index': 1,
#    'fit_time': 0.17874598503112793,
#    'score_time': 0.016605854034423828},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 22,
#    'split_index': 1,
#    'fit_time': 0.18119025230407715,
#    'score_time': 0.017783641815185547},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 1,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 23,
#    'split_index': 1,
#    'fit_time': 0.18387985229492188,
#    'score_time': 0.01711273193359375}],
#  2: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 0,
#    'split_index': 2,
#    'fit_time': 0.08983182907104492,
#    'score_time': 0.0068628787994384766},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 1,
#    'split_index': 2,
#    'fit_time': 0.06694293022155762,
#    'score_time': 0.00753474235534668},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 2,
#    'split_index': 2,
#    'fit_time': 0.06236910820007324,
#    'score_time': 0.006526947021484375},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 3,
#    'split_index': 2,
#    'fit_time': 0.060658931732177734,
#    'score_time': 0.006716251373291016},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 4,
#    'split_index': 2,
#    'fit_time': 0.06340289115905762,
#    'score_time': 0.006758928298950195},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 5,
#    'split_index': 2,
#    'fit_time': 0.06046795845031738,
#    'score_time': 0.006667137145996094},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 6,
#    'split_index': 2,
#    'fit_time': 0.062294960021972656,
#    'score_time': 0.0067369937896728516},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 7,
#    'split_index': 2,
#    'fit_time': 0.061322927474975586,
#    'score_time': 0.0066297054290771484},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 8,
#    'split_index': 2,
#    'fit_time': 0.06249594688415527,
#    'score_time': 0.006626129150390625},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 9,
#    'split_index': 2,
#    'fit_time': 0.06044793128967285,
#    'score_time': 0.006949901580810547},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 10,
#    'split_index': 2,
#    'fit_time': 0.06188702583312988,
#    'score_time': 0.006710052490234375},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 2,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 11,
#    'split_index': 2,
#    'fit_time': 0.06051921844482422,
#    'score_time': 0.006517171859741211},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 12,
#    'split_index': 2,
#    'fit_time': 0.18494296073913574,
#    'score_time': 0.018325090408325195},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 13,
#    'split_index': 2,
#    'fit_time': 0.21643376350402832,
#    'score_time': 0.017423152923583984},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 14,
#    'split_index': 2,
#    'fit_time': 0.19684576988220215,
#    'score_time': 0.018759965896606445},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 15,
#    'split_index': 2,
#    'fit_time': 0.1818981170654297,
#    'score_time': 0.0169370174407959},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 16,
#    'split_index': 2,
#    'fit_time': 0.19366097450256348,
#    'score_time': 0.0172116756439209},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 17,
#    'split_index': 2,
#    'fit_time': 0.1827099323272705,
#    'score_time': 0.01705622673034668},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 18,
#    'split_index': 2,
#    'fit_time': 0.20942997932434082,
#    'score_time': 0.019403934478759766},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 19,
#    'split_index': 2,
#    'fit_time': 0.1815049648284912,
#    'score_time': 0.016949176788330078},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 20,
#    'split_index': 2,
#    'fit_time': 0.18625998497009277,
#    'score_time': 0.017306804656982422},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 21,
#    'split_index': 2,
#    'fit_time': 0.18332505226135254,
#    'score_time': 0.017130136489868164},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 22,
#    'split_index': 2,
#    'fit_time': 0.1911182403564453,
#    'score_time': 0.01926112174987793},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 2,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 23,
#    'split_index': 2,
#    'fit_time': 0.18672895431518555,
#    'score_time': 0.018045902252197266}],
#  3: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 0,
#    'split_index': 3,
#    'fit_time': 0.0615229606628418,
#    'score_time': 0.006691694259643555},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 1,
#    'split_index': 3,
#    'fit_time': 0.06307506561279297,
#    'score_time': 0.007185935974121094},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 2,
#    'split_index': 3,
#    'fit_time': 0.0646669864654541,
#    'score_time': 0.007384061813354492},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 3,
#    'split_index': 3,
#    'fit_time': 0.06018996238708496,
#    'score_time': 0.00678706169128418},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 4,
#    'split_index': 3,
#    'fit_time': 0.06208992004394531,
#    'score_time': 0.006957054138183594},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 5,
#    'split_index': 3,
#    'fit_time': 0.059737205505371094,
#    'score_time': 0.006700992584228516},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 6,
#    'split_index': 3,
#    'fit_time': 0.06046104431152344,
#    'score_time': 0.006559133529663086},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 7,
#    'split_index': 3,
#    'fit_time': 0.06031322479248047,
#    'score_time': 0.006495952606201172},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 8,
#    'split_index': 3,
#    'fit_time': 0.06069684028625488,
#    'score_time': 0.006676912307739258},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 9,
#    'split_index': 3,
#    'fit_time': 0.05934500694274902,
#    'score_time': 0.0064809322357177734},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 10,
#    'split_index': 3,
#    'fit_time': 0.061251163482666016,
#    'score_time': 0.0063838958740234375},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 3,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 11,
#    'split_index': 3,
#    'fit_time': 0.05967402458190918,
#    'score_time': 0.006758928298950195},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 12,
#    'split_index': 3,
#    'fit_time': 0.19243288040161133,
#    'score_time': 0.018412113189697266},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 13,
#    'split_index': 3,
#    'fit_time': 0.17915582656860352,
#    'score_time': 0.016871929168701172},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 14,
#    'split_index': 3,
#    'fit_time': 0.18996524810791016,
#    'score_time': 0.01730203628540039},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 15,
#    'split_index': 3,
#    'fit_time': 0.1772911548614502,
#    'score_time': 0.0167849063873291},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 16,
#    'split_index': 3,
#    'fit_time': 0.1825089454650879,
#    'score_time': 0.017447948455810547},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 17,
#    'split_index': 3,
#    'fit_time': 0.1789569854736328,
#    'score_time': 0.017178773880004883},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 18,
#    'split_index': 3,
#    'fit_time': 0.1907048225402832,
#    'score_time': 0.017013072967529297},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 19,
#    'split_index': 3,
#    'fit_time': 0.17775321006774902,
#    'score_time': 0.016891956329345703},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 20,
#    'split_index': 3,
#    'fit_time': 0.18211674690246582,
#    'score_time': 0.01706218719482422},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 21,
#    'split_index': 3,
#    'fit_time': 0.17730998992919922,
#    'score_time': 0.01717209815979004},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 22,
#    'split_index': 3,
#    'fit_time': 0.20003914833068848,
#    'score_time': 0.019588232040405273},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 3,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 23,
#    'split_index': 3,
#    'fit_time': 0.19028687477111816,
#    'score_time': 0.018227815628051758}],
#  4: [{'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 0,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 0,
#    'split_index': 4,
#    'fit_time': 0.06164193153381348,
#    'score_time': 0.007023811340332031},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 1,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 1,
#    'split_index': 4,
#    'fit_time': 0.06393074989318848,
#    'score_time': 0.007440090179443359},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 2,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 2,
#    'split_index': 4,
#    'fit_time': 0.06493616104125977,
#    'score_time': 0.007421255111694336},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 3,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 3,
#    'split_index': 4,
#    'fit_time': 0.05938220024108887,
#    'score_time': 0.006587028503417969},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 4,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 4,
#    'split_index': 4,
#    'fit_time': 0.06443119049072266,
#    'score_time': 0.006994962692260742},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 5,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 5,
#    'split_index': 4,
#    'fit_time': 0.060112953186035156,
#    'score_time': 0.006888866424560547},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 6,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 6,
#    'split_index': 4,
#    'fit_time': 0.06232023239135742,
#    'score_time': 0.007150888442993164},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 7,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 7,
#    'split_index': 4,
#    'fit_time': 0.05985522270202637,
#    'score_time': 0.006641864776611328},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 8,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 8,
#    'split_index': 4,
#    'fit_time': 0.06166505813598633,
#    'score_time': 0.0066983699798583984},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 9,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 9,
#    'split_index': 4,
#    'fit_time': 0.06068611145019531,
#    'score_time': 0.006704807281494141},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 10,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 10,
#    'split_index': 4,
#    'fit_time': 0.06127119064331055,
#    'score_time': 0.006871223449707031},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 11,
#    'split_index': 4,
#    'params': {'n_estimators': 100,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 11,
#    'split_index': 4,
#    'fit_time': 0.05955195426940918,
#    'score_time': 0.006664276123046875},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 12,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 12,
#    'split_index': 4,
#    'fit_time': 0.1950080394744873,
#    'score_time': 0.018007755279541016},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 13,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 13,
#    'split_index': 4,
#    'fit_time': 0.1834099292755127,
#    'score_time': 0.0173947811126709},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 14,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 14,
#    'split_index': 4,
#    'fit_time': 0.18633723258972168,
#    'score_time': 0.017332077026367188},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 15,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': None,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 15,
#    'split_index': 4,
#    'fit_time': 0.18107104301452637,
#    'score_time': 0.017068147659301758},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 16,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 16,
#    'split_index': 4,
#    'fit_time': 0.18536901473999023,
#    'score_time': 0.017421960830688477},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 17,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 17,
#    'split_index': 4,
#    'fit_time': 0.18053770065307617,
#    'score_time': 0.017281055450439453},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 18,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 18,
#    'split_index': 4,
#    'fit_time': 0.18554973602294922,
#    'score_time': 0.017190933227539062},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 19,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 10,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 19,
#    'split_index': 4,
#    'fit_time': 0.18045997619628906,
#    'score_time': 0.017410755157470703},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 20,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 20,
#    'split_index': 4,
#    'fit_time': 0.18545985221862793,
#    'score_time': 0.017547130584716797},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 21,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 2,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 21,
#    'split_index': 4,
#    'fit_time': 0.18088412284851074,
#    'score_time': 0.017494916915893555},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 22,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 1,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 22,
#    'split_index': 4,
#    'fit_time': 0.22197318077087402,
#    'score_time': 0.019841909408569336},
#   {'stage': 'fit_and_score',
#    'event': 'estimator_cloned',
#    'candidate_index': 23,
#    'split_index': 4,
#    'params': {'n_estimators': 300,
#     'max_depth': 20,
#     'min_samples_split': 5,
#     'min_samples_leaf': 2,
#     'bootstrap': True}},
#   {'stage': 'timing',
#    'event': 'timing_recorded',
#    'candidate_index': 23,
#    'split_index': 4,
#    'fit_time': 0.1930248737335205,
#    'score_time': 0.01853013038635254}]}
